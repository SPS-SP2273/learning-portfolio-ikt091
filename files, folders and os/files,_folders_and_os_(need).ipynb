# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %%
# Your code here

# %% [markdown]
# ### 1.2 More about relative paths

# %%
# Your code here

# %% [markdown]
# ### 1.3 Path separator

# %%
# Your code here

# %% [markdown]
# ### Text files vs Binary files

# %%
# Your code here

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
with open('spectrum-01.txt', 'r') as file: # with frees you from worrying about closing the file stream after you're done
    file_content = file.read()
    
print(file_content)

#'r' means to read
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
# Write the following into a file

text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

with open('my-text-once.txt', 'w') as file: # w means to write a new file into existence
    file.write(text)
    
# new file created with its name having been specified already

# %%
# Write a line at a time

text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

with open('my-text-once.txt', 'w') as file: # w means to write a new file into existence
    for line in text.splitlines():
        file.writelines(line)
    
# new file created with its name having been specified already

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os
import glob
import shutil

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.','all-data','sg-data','data-01-txt')
print(path)
# Out:
# .\all-data\sg-data\data-01-txt

# %%
# Your code here

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['John','People','Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 os.mkdir('people')
#       3 for person in ['John','People','Ringo']:
#       4     path = os.path.join('people', person)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'people'

# %%
os.mkdir('people_5')

for person in ['John','People','Ringo']:
    path = os.path.join('people_5', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 os.mkdir('people_5')
#       3 for person in ['John','People','Ringo']:
#       4     path = os.path.join('people_5', person)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'people_5'

# %%
x = 'people_8'
os.mkdir(x)

for person in ['John','People','Ringo']:
    path = os.path.join(x, person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating people_8\John
# Creating people_8\People
# Creating people_8\Ringo

# %%
os.mkdir('ppl') 

for person in ['try','People2','Ringo2']:
    path = os.path.join('ppl', person)
#     print(f'Creating {path}')
    os.mkdir(path)

# %%
os.mkdir('Shelby Family') 

for person in ['Tommy','Jon','Arthur']:
    path = os.path.join('Shelby Family', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating Shelby Family\Tommy
# Creating Shelby Family\Jon
# Creating Shelby Family\Arthur

# %% [markdown]
# ### 2.4 Checking for existence

# %%
# Using try-except

for person in ['John','Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people\John already exists; skipping creation.
# Creating people\Paul
# people\Ringo already exists; skipping creation.

# %%
# Using os.path.exists()

for person in ['John', 'Paul', 'Ringo', 'Django']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people\John already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.
# Creating people\Django

# %% [markdown]
# ### 2.5 Copying files

# %%
# Copying file sp2273.png into each folder

for person in ['John', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people\John
# Copied file to people\Paul
# Copied file to people\Ringo

# %%
# Have all the images in a folder called imgs in each person's directory
for person in ['John', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)
        
    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')
    
    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people\John\imgs\sp2273_logo.png
# Moved logo to people\Paul\imgs\sp2273_logo.png
# Moved logo to people\Ringo\imgs\sp2273_logo.png

# %% [markdown]
# ### 2.6 Listing files

# %%
# to find all files in current directory HELP checkpoints file not shown

glob.glob('*')

# * is a wildcard and is read as 'anything'
# anything in folder is given
# Out:
# ['files,_folders_and_os_(need).ipynb',
#  'my-text-once.txt',
#  'people',
#  'ppl',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
glob.glob('peo*')

#Asking glob to give those files that match the pattern 'peo'
# Out:
# ['people']

# %%
glob.glob('peo*/*')
          
# To know what is inside the folder 'people'
# Out:
# []

# %%
glob.glob('people/**', recursive = True)

# show entire content of people folder 
# dif through all sub-file directories then 2 wildcards used
# Out:
# ['people\\',
#  'people\\Django',
#  'people\\John',
#  'people\\John\\imgs',
#  'people\\John\\imgs\\sp2273_logo.png',
#  'people\\Paul',
#  'people\\Paul\\imgs',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\People',
#  'people\\Ringo',
#  'people\\Ringo\\imgs',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('people/**/*png', recursive = True)

# show entire content of people folder 
# dif through all sub-file directories then 2 wildcards used
# only want one file type
# Out:
# ['people\\John\\imgs\\sp2273_logo.png',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('files, folders and os/**/*TXT', recursive = True) #HELP

# show entire content of people folder 
# dif through all sub-file directories then 2 wildcards used
# only want one file type
# Out:
# []

# %% [markdown]
# ### 2.7 Moving about

# %%
os.chdir('people/Ringo') #HELP
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 os.chdir('people/Ringo')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'people/Ringo'

# %%
os.chdir('people') #HELP

# %%
os.getcwd()

#Where you are currently
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people'

# %%
glob.glob('Ringo*')
# Out:
# []

# %%
glob.glob('peo*')
# Out:
# []

# %% [markdown]
# ### 2.8 Extracting Info

# %%
# extract filename, folder or extension
# by simple string manipulation

path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1] # split path where
# separator occurred 
print(filename, extension)
# Out:
# people/Ringo/imgs/sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'

# %%
os.path.split(path) # Split file name from the rest HELP
# Out:
# ('people', 'Django')

# %%
os.path.splitext(path) # Split extension HELP
# Out:
# ('people\\Django', '')

# %%
os.path.dirname(path) # Show the directory HELP
# Out:
# 'people'

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
os.remove('people/Ringo/imgs/sp2273_logo.png')
# won't work with directories HELP
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 os.remove('people/Ringo/imgs/sp2273_logo.png')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'people/Ringo/imgs/sp2273_logo.png'

# %%
# for empty directory HELP

os.rmdir('people/Ringo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [36], line 3
#       1 # for empty directory
# ----> 3 os.rmdir('people/Ringo')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'people/Ringo'

# %%
# for a directory with files HELP

shutil.rmtree('people/Ringo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [38], line 3
#       1 # for a directory with files
# ----> 3 shutil.rmtree('people/Ringo')
#
# File ~\miniconda3\lib\shutil.py:757, in rmtree(path, ignore_errors, onerror)
#     755     # can't continue even if onerror hook returns
#     756     return
# --> 757 return _rmtree_unsafe(path, onerror)
#
# File ~\miniconda3\lib\shutil.py:608, in _rmtree_unsafe(path, onerror)
#     606         entries = list(scandir_it)
#     607 except OSError:
# --> 608     onerror(os.scandir, path, sys.exc_info())
#     609     entries = []
#     610 for entry in entries:
#
# File ~\miniconda3\lib\shutil.py:605, in _rmtree_unsafe(path, onerror)
#     603 def _rmtree_unsafe(path, onerror):
#     604     try:
# --> 605         with os.scandir(path) as scandir_it:
#     606             entries = list(scandir_it)
#     607     except OSError:
# ...

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
# 1. Figure out where I am currently with os.getcwd()

os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# 2. Create a new directory (folder) using os.mkdir called python_today

os.mkdir('python_today')

# %%
# 3. use os.chdir() to change into this directory 

# path_to_destination = os.path.join('people')
# shutil.copy('python_today', path_to_destination)
# print(f'Copied python_today to {path_to_destination}')

os.chdir('C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people')

os.chdir('C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today')

# Verify I am where I want to  be

os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# CORRECT CODE
for number in range(1,51):
    ze = str(number).zfill(2)
    os.mkdir(f'new_directory_{ze}')

# %%
# CORRECT CODE
x = glob.glob('**')
x
# Out:
# ['new_directory_01',
#  'new_directory_02',
#  'new_directory_03',
#  'new_directory_04',
#  'new_directory_05',
#  'new_directory_06',
#  'new_directory_07',
#  'new_directory_08',
#  'new_directory_09',
#  'new_directory_10',
#  'new_directory_11',
#  'new_directory_12',
#  'new_directory_13',
#  'new_directory_14',
#  'new_directory_15',
#  'new_directory_16',
#  'new_directory_17',
#  'new_directory_18',
#  'new_directory_19',
#  'new_directory_20',
#  'new_directory_21',
#  'new_directory_22',
#  'new_directory_23',
#  'new_directory_24',
#  'new_directory_25',
#  'new_directory_26',
#  'new_directory_27',
#  'new_directory_28',
#  'new_directory_29',
#  'new_directory_30',
#  'new_directory_31',
#  'new_directory_32',
#  'new_directory_33',
#  'new_directory_34',
#  'new_directory_35',
#  'new_directory_36',
#  'new_directory_37',
#  'new_directory_38',
#  'new_directory_39',
#  'new_directory_40',
#  'new_directory_41',
#  'new_directory_42',
#  'new_directory_43',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
range(1, 10, 2)

# %%
# CORRECT CODE
for i in range(1, len(x), 2):
    os.rmdir(f"new_directory_{i:02}") #DO NOT RUN

# %%
# CORRECT CODE
# 4. remove all 0dd numbered new directories

for i in range(len(x)):
    if i%2 == 0: # every element with an even numbered index is the one labelled an odd number
        os.rmdir(x[i])
        
#DO NOT RUN

# %%
# CORRECT CODE
os.listdir() # Check that we deleted right
# Out:
# ['new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50']

# %%
for i in range(0,10,4):
    print(i)
# Out:
# 0
# 4
# 8

# %%
# CORRECT CODE
# 5. rename every 5th new_directory
y = 0

for i in range(10, 51, 10):
    y += 5
    os.rename(f'new_directory_{i}' , f'haha_{y:02}')
# DO NOT RUN

# %%
# CORRECT CODE
x = os.listdir() 
x
# Out:
# ['haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %%
# CORRECT CODE
# use os.path.exists() to account for missing files

a = 5
# for i in x:
#     path = os.path.join('python_today', )


for i in x:
    if os.path.exists(f'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today\\haha_{a:02}'):
        print(f'haha_{a:02} already exists')
        a += 5
    

    #     else:
#         os.mkdir(path)
#         print(f'Creating {path}')

# path = os.path.join('C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today\\haha_05')
# os.path.exists('C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today\\haha_05')
# Out:
# haha_05 already exists
# haha_10 already exists
# haha_15 already exists
# haha_20 already exists
# haha_25 already exists

# %%
# CORRECT CODE
os.chdir('C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os'

# %%
# CORRECT CODE
x
# Out:
# ['haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os'

# %%
# CORRECT CODE
# 6. Copy module logo to all haha folders
# Use glob to get all details of haha folders

path_to_destination = os.path.join('people', 'python_today', '**haha*') # ** all sub-directories, * means any numbers
# print(path_to_destination)
destination_list = glob.glob(path_to_destination, recursive=True)
destination_list
# Out:
# ['people\\python_today\\haha_05',
#  'people\\python_today\\haha_10',
#  'people\\python_today\\haha_15',
#  'people\\python_today\\haha_20',
#  'people\\python_today\\haha_25']

# %%
# CORRECT CODE
# 6. Copy module logo to all haha folders
# shutil.copy to copy all files

for a in destination_list:
#     path_to_destination = (f'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today\\haha_{a:02}')
    shutil.copy('sp2273_logo.png', a)

# %%
# CORRECT CODE
# 6. Copy module logo to all haha folders
# os.listdir() to check handiwork

path_to_new_destination = os.path.join('haha*')
new_destination = glob.glob(path_to_new_destination, recursive = True)
new_destination
# Out:
# ['haha_05', 'haha_10', 'haha_15', 'haha_20', 'haha_25']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# CORRECT CODE
# 6. Copy module logo to all haha folders
# os.listdir() to check handiwork

for i in new_destination:
    os.chdir(i)
    print(os.listdir())
    print(os.getcwd())
    os.chdir('..')
# Out:
# ['sp2273_logo.png']
# C:\Users\ASUS\Documents\learning-portfolio-ikt091\files, folders and os\people\python_today\haha_05
# ['sp2273_logo.png']
# C:\Users\ASUS\Documents\learning-portfolio-ikt091\files, folders and os\people\python_today\haha_10
# ['sp2273_logo.png']
# C:\Users\ASUS\Documents\learning-portfolio-ikt091\files, folders and os\people\python_today\haha_15
# ['sp2273_logo.png']
# C:\Users\ASUS\Documents\learning-portfolio-ikt091\files, folders and os\people\python_today\haha_20
# ['sp2273_logo.png']
# C:\Users\ASUS\Documents\learning-portfolio-ikt091\files, folders and os\people\python_today\haha_25

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today\\haha_05'

# %%
# CORRECT CODE
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# CORRECT CODE
glob.glob('**haha*/sp2273_logo.png')
# Out:
# ['haha_05\\sp2273_logo.png',
#  'haha_10\\sp2273_logo.png',
#  'haha_15\\sp2273_logo.png',
#  'haha_20\\sp2273_logo.png',
#  'haha_25\\sp2273_logo.png']

# %%
# CORRECT CODE
os.listdir()
# Out:
# ['haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %%
# CORRECT CODE
# Using glob.glob() to check handiwork

glob.glob('haha*/*')
# Out:
# ['haha_05\\sp2273_logo.png',
#  'haha_10\\sp2273_logo.png',
#  'haha_15\\sp2273_logo.png',
#  'haha_20\\sp2273_logo.png',
#  'haha_25\\sp2273_logo.png']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
month_dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
month_dictionary['jan']
# Out:
# '01'

# %%
# CORRECT CODE
# 1. function to re-write file names & 2. return new file name


month_dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
#     for key, value in month_dictionary.items():
#         old_file_name = f'{key}-*_*.txt'
#         new_file_name = f'{value}-*_*.txt'
    month = old_file_name[0:3]
#     change_to_hyphen = old_file_name[6]
    new_file_name = month_dictionary[month] +  old_file_name[3:6] + '-' + old_file_name[7:]
    return new_file_name
        

rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
# CORRECT CODE
# 3.  Use a for loop to apply the function rename_my_file(old_file_name)

old_name_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for old_file_name in old_name_list:
    new_file_name = rename_my_file(old_file_name)
    print(new_file_name)
# Out:
# 10-08-singapore.txt
# 07-10-cairo.txt
# 05-15-dhaka.txt
# 05-13-cairo.txt
# 10-21-cairo.txt
# 01-10-singapore.txt
# 06-20-tokyo.txt
# 08-06-jakarta.txt
# 12-21-karachi.txt
# 01-01-tokyo.txt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# CORRECT CODE
path_to_destination = os.path.join('files, folders and os', 'people') # file wont be found since you are in python_today (at the time)
# os.chdir('..') # Use '..' to get out (move up one to parent directory)
os.chdir('os-collaboration-exercise-data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
glob.glob('*txt')
# Out:
# ['apr-01_melbourne.txt',
#  'apr-01_shanghai.txt',
#  'apr-01_singapore.txt',
#  'apr-02_cairo.txt',
#  'apr-02_jakarta.txt',
#  'apr-02_karachi.txt',
#  'apr-02_shanghai.txt',
#  'apr-03_manila.txt',
#  'apr-03_osaka.txt',
#  'apr-03_singapore.txt',
#  'apr-03_tokyo.txt',
#  'apr-04_manila.txt',
#  'apr-04_melbourne.txt',
#  'apr-04_shanghai.txt',
#  'apr-04_singapore.txt',
#  'apr-05_karachi.txt',
#  'apr-05_melbourne.txt',
#  'apr-05_shanghai.txt',
#  'apr-05_singapore.txt',
#  'apr-06_cairo.txt',
#  'apr-06_jakarta.txt',
#  'apr-06_karachi.txt',
#  'apr-06_manila.txt',
#  'apr-07_cairo.txt',
#  'apr-07_manila.txt',
#  'apr-07_melbourne.txt',
#  'apr-07_osaka.txt',
#  'apr-07_singapore.txt',
#  'apr-07_tokyo.txt',
#  'apr-08_shanghai.txt',
#  'apr-10_cairo.txt',
#  'apr-10_manila.txt',
#  'apr-10_melbourne.txt',
#  'apr-10_shanghai.txt',
#  'apr-10_singapore.txt',
#  'apr-10_tokyo.txt',
#  'apr-11_melbourne.txt',
#  'apr-11_shanghai.txt',
#  'apr-11_tokyo.txt',
# ...

# %%
# CORRECT CODE
# 4. In conjunction with glob, use rename function to rename all .txt files

old_names = glob.glob('*txt')

for old_file_name in old_names:
    new_file_name = rename_my_file(old_file_name)
    os.rename(old_file_name, new_file_name)
    
new_names = os.listdir()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [84], line 6
#       3 old_names = glob.glob('*txt')
#       5 for old_file_name in old_names:
# ----> 6     new_file_name = rename_my_file(old_file_name)
#       7     os.rename(old_file_name, new_file_name)
#       9 new_names = os.listdir()
#
# Cell In [67], line 17, in rename_my_file(old_file_name)
#      15     month = old_file_name[0:3]
#      16 #     change_to_hyphen = old_file_name[6]
# ---> 17     new_file_name = month_dictionary[month] +  old_file_name[3:6] + '-' + old_file_name[7:]
#      18     return new_file_name
#
# KeyError: '01-'

# %%
# CORRECT CODE
os.listdir()
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
# 5. Use a for loop to create a folder for each city

list_of_countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for country in list_of_countries:
#     path = os.path.join('os-collaboration-exercise-data', country)
#     print(f'Creating {path}')
    os.mkdir(country)

# %%
# CORRECT CODE
os.listdir()
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os'

# %%
# CORRECT CODE
os.chdir('people/python_today')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\python_today'

# %%
# CORRECT CODE
# os.chdir('os-collaboration-exercise-data')
# os.getcwd()
os.chdir('..')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people'

# %%
# CORRECT CODE
os.chdir('os-collaboration-exercise-data')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
glob.glob('*cairo.txt')
# Out:
# ['01-02-cairo.txt',
#  '01-03-cairo.txt',
#  '01-04-cairo.txt',
#  '01-05-cairo.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-09-cairo.txt',
#  '01-11-cairo.txt',
#  '01-12-cairo.txt',
#  '01-13-cairo.txt',
#  '01-15-cairo.txt',
#  '01-16-cairo.txt',
#  '01-19-cairo.txt',
#  '01-20-cairo.txt',
#  '01-21-cairo.txt',
#  '01-23-cairo.txt',
#  '01-27-cairo.txt',
#  '01-30-cairo.txt',
#  '02-10-cairo.txt',
#  '02-17-cairo.txt',
#  '02-20-cairo.txt',
#  '02-22-cairo.txt',
#  '02-25-cairo.txt',
#  '02-26-cairo.txt',
#  '03-05-cairo.txt',
#  '03-06-cairo.txt',
#  '03-12-cairo.txt',
#  '03-14-cairo.txt',
#  '03-19-cairo.txt',
#  '03-24-cairo.txt',
#  '04-02-cairo.txt',
#  '04-06-cairo.txt',
#  '04-07-cairo.txt',
#  '04-10-cairo.txt',
#  '04-12-cairo.txt',
#  '04-13-cairo.txt',
#  '04-14-cairo.txt',
#  '04-15-cairo.txt',
#  '04-17-cairo.txt',
#  '04-20-cairo.txt',
#  '04-21-cairo.txt',
#  '04-22-cairo.txt',
#  '04-23-cairo.txt',
#  '04-24-cairo.txt',
#  '05-01-cairo.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os'

# %%
# CORRECT CODE
os.path.join('people', 'os-collaboration-exercise-data')
# os.chdir('people')
os.chdir('os-collaboration-exercise-data')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
cairo_list = glob.glob('*cairo.*')

for cairo_file in cairo_list:
    path_to_destination = os.path.join('Cairo')
    shutil.copy(cairo_file, path_to_destination)

# %%
# CORRECT CODE
os.chdir('Cairo')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data\\Cairo'

# %%
# CORRECT CODE
os.listdir()
# Out:
# ['01-02-cairo.txt',
#  '01-03-cairo.txt',
#  '01-04-cairo.txt',
#  '01-05-cairo.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-09-cairo.txt',
#  '01-11-cairo.txt',
#  '01-12-cairo.txt',
#  '01-13-cairo.txt',
#  '01-15-cairo.txt',
#  '01-16-cairo.txt',
#  '01-19-cairo.txt',
#  '01-20-cairo.txt',
#  '01-21-cairo.txt',
#  '01-23-cairo.txt',
#  '01-27-cairo.txt',
#  '01-30-cairo.txt',
#  '02-10-cairo.txt',
#  '02-17-cairo.txt',
#  '02-20-cairo.txt',
#  '02-22-cairo.txt',
#  '02-25-cairo.txt',
#  '02-26-cairo.txt',
#  '03-05-cairo.txt',
#  '03-06-cairo.txt',
#  '03-12-cairo.txt',
#  '03-14-cairo.txt',
#  '03-19-cairo.txt',
#  '03-24-cairo.txt',
#  '04-02-cairo.txt',
#  '04-06-cairo.txt',
#  '04-07-cairo.txt',
#  '04-10-cairo.txt',
#  '04-12-cairo.txt',
#  '04-13-cairo.txt',
#  '04-14-cairo.txt',
#  '04-15-cairo.txt',
#  '04-17-cairo.txt',
#  '04-20-cairo.txt',
#  '04-21-cairo.txt',
#  '04-22-cairo.txt',
#  '04-23-cairo.txt',
#  '04-24-cairo.txt',
#  '05-01-cairo.txt',
# ...

# %%
# CORRECT CODE
os.chdir('..')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
glob.glob('*singapore.txt')
# Out:
# ['01-15-singapore.txt',
#  '02-01-singapore.txt',
#  '02-02-singapore.txt',
#  '02-03-singapore.txt',
#  '02-04-singapore.txt',
#  '02-05-singapore.txt',
#  '02-08-singapore.txt',
#  '02-12-singapore.txt',
#  '02-13-singapore.txt',
#  '02-14-singapore.txt',
#  '02-15-singapore.txt',
#  '02-17-singapore.txt',
#  '02-19-singapore.txt',
#  '02-20-singapore.txt',
#  '02-23-singapore.txt',
#  '02-24-singapore.txt',
#  '02-27-singapore.txt',
#  '03-05-singapore.txt',
#  '04-01-singapore.txt',
#  '04-03-singapore.txt',
#  '04-04-singapore.txt',
#  '04-05-singapore.txt',
#  '04-07-singapore.txt',
#  '04-10-singapore.txt',
#  '04-12-singapore.txt',
#  '04-13-singapore.txt',
#  '04-14-singapore.txt',
#  '04-15-singapore.txt',
#  '04-19-singapore.txt',
#  '04-21-singapore.txt',
#  '04-22-singapore.txt',
#  '04-23-singapore.txt',
#  '04-25-singapore.txt',
#  '04-26-singapore.txt',
#  '05-01-singapore.txt',
#  '05-04-singapore.txt',
#  '05-06-singapore.txt',
#  '05-08-singapore.txt',
# ...

# %%
# CORRECT CODE
glob.glob('**')
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
list_of_countries = [ 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']


# # Method 1
# dhaka_files = glob.glob('*dhaka.txt')

# for dhaka_file in remianing_files:
#     path_to_destination = os.path.join('Dhaka')
#     shutil.move('os-collaboration-exercise-data/cairo_file', path_to_destination)
    
    
# Method 2
for country in list_of_countries:
    specific_country_files = glob.glob(f'*{country}.*')
    
    for specific_country_file in specific_country_files:
#         current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
#         new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')
#         shutil.move(current_path_of_logo, new_path_of_logo)
        new_path_of_file = os.path.join(country, specific_country_file)
        shutil.move(specific_country_file, new_path_of_file)
# print(current_path_of_file)
# print(specific_country_file)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data'

# %%
# CORRECT CODE
os.chdir('Singapore')
os.listdir()
# Out:
# ['01-15-singapore.txt',
#  '02-01-singapore.txt',
#  '02-02-singapore.txt',
#  '02-03-singapore.txt',
#  '02-04-singapore.txt',
#  '02-05-singapore.txt',
#  '02-08-singapore.txt',
#  '02-12-singapore.txt',
#  '02-13-singapore.txt',
#  '02-14-singapore.txt',
#  '02-15-singapore.txt',
#  '02-17-singapore.txt',
#  '02-19-singapore.txt',
#  '02-20-singapore.txt',
#  '02-23-singapore.txt',
#  '02-24-singapore.txt',
#  '02-27-singapore.txt',
#  '03-05-singapore.txt',
#  '04-01-singapore.txt',
#  '04-03-singapore.txt',
#  '04-04-singapore.txt',
#  '04-05-singapore.txt',
#  '04-07-singapore.txt',
#  '04-10-singapore.txt',
#  '04-12-singapore.txt',
#  '04-13-singapore.txt',
#  '04-14-singapore.txt',
#  '04-15-singapore.txt',
#  '04-19-singapore.txt',
#  '04-21-singapore.txt',
#  '04-22-singapore.txt',
#  '04-23-singapore.txt',
#  '04-25-singapore.txt',
#  '04-26-singapore.txt',
#  '05-01-singapore.txt',
#  '05-04-singapore.txt',
#  '05-06-singapore.txt',
#  '05-08-singapore.txt',
# ...

# %%
# CORRECT CODE
os.chdir('..')
os.chdir('Singapore')
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data\\Singapore'

# %%
os.listdir()
# Out:
# []

# %%
# CORRECT CODE
os.chdir('..')
os.listdir()
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data\\Singapore'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data\\Cairo'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ASUS\\Documents\\learning-portfolio-ikt091\\files, folders and os\\people\\os-collaboration-exercise-data\\Cairo'
