# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# ## 1 Comparing the two ‘dialects’

# %% [markdown]
# ### 1.1 Some nomenclature

# %% [markdown]
# difference  between matplotlib figure and axis
#
# figure - full canvas to draw stuff on
#
# axis - individual mathematical axes used for plotting

# %% [markdown]
# ### 1.2 We need some data.

# %%
import numpy as np
import os
import glob
import shutil
import math
from matplotlib import pyplot as plt

# %%
# generate some data

x = np.linspace(-np.pi, np.pi, num = 100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# pypl
plt.plot(x, cos_x, label = 'cos x')
plt.plot(x, sin_x, label = 'sin x')
plt.legend()

plt.show()

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)
ax.plot(x, cos_x, label = 'cos_x')
ax.plot(x, sin_x, label = 'sin_x')
ax.legend()

plt.show()

# %% [markdown]
# ### 1.3 Here comes the comparison

# %%
# Your code here

# %% [markdown]
# ## 2 Using the OO Interface

# %% [markdown]
# ### 2.1 Getting ax

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 2) #whats happening
ax.plot(x, cos_x, label = 'cos_x')
ax.plot(x, sin_x, label = 'sin_x')
ax.legend()

plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 2
#       1 fig, ax = plt.subplots(ncols = 1, nrows = 2)
# ----> 2 ax.plot(x, cos_x, label = 'cos_x')
#       3 ax.plot(x, sin_x, label = 'sin_x')
#       4 ax.legend()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# ### 2.2 What is ax

# %%
type(ax)
# Out:
# numpy.ndarray

# %%
ax.shape # how many things ax has
# Out:
# (2,)

# %%
type(ax[0]) # what is contained in x
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(ax[1]) # what is contained in x
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# ### 2.3 Plots in a column

# %%
ax[0].plot(x, cos_x, label = 'cos_x') # First plot

ax[1].plot(x, sin_x, label = 'sin x') # Second plot

# %% [markdown]
# ### 2.4 Legends

# %%
# call legend for each axis

ax[0].legend()

ax[1].legend()

# rather do it with a for loop

for a in ax: # iterate through items in ax
    a.legend() # 
    a.grid(alpha = .25) # grid added to each of the axes

# %% [markdown]
# ### 2.5 Tweaks

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (5,10) # 10 by 5 inches
                      sharex = True)

ax[1].set_xlabel('$x$')

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (5,10), # 10 by 5 inches
                      sharex = True)

ax[0].set_xlabel('$x$')
ax[1].set_xlabel('$x$')

ax[0].fill_between(x, 0, cos_x, alpha = .25) # plotting the fella from 0
ax[1].fill_between(x, 0, sin_x, alpha = .25) # plotting the fella from 0

fig.suptitle(r'$\sin(x)$ and $\cos(x)$') # adding super title

fig.tight_layout() # make necessary adjustments to layout to make plot look nice

plt.show()

# %% [markdown]
# ## 3 More rows and columns

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 4), sharex = 'col', sharey = 'col')

top_left, top_right, bottom_left, bottom_right = ax.flatten() # some variables to access the axes and improve readability 

# x data for plotting

x1 = np.linspace(0, 10, 100)

x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1))
top_right.plot(x2, 2*np.ones_like(x2))
bottom_left.plot(x1, 3*np.ones_like(x1))
bottom_right.plot(x2, 4**np.ones_like(x2))

for a in ax.flatten(): # call the grids' thickness one shot
    a.grid(alpha=.25)
    
plt.tight_layout()

plt.show()

# %% [markdown]
# ### 3.1 Using ax

# %%
ax[0, 0].plot(x1, np.ones_like(x1))
ax[0, 1].plot(x2, np.ones_like(x2))
ax[1, 0].plot(x3, np.ones_like(x3))
ax[1, 1].plot(x4, np.ones_like(x4))

# OR use a familiar variable to tweak each axes separately

top_left = ax[0,0]
top_right = ax[0,1]
bottom_left = ax[1,0]
bottom_right = ax[1,1]

# OR use ax.flatten() to flatten the 2D arrays

top_left, top_right, bottom_left, bottom_right = ax.flatten() # all 2D arrays flattened into a 1D array

# %% [markdown]
# ### 3.2 Sharing axes

# %%
# makes plot more compact by sharing x and y axes using sharex




fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize =(10,4), sharex = True, sharey = True)

top_left, top_right, bottom_left, bottom_right = ax.flatten()

x1 = np.linspace(0, 10, 100)

x2 = np.linspace(10, 20, 100)

top_left.plot(x1, np.ones_like(x1), label = 'x1 VS x1')
top_right.plot(x2, 2*np.ones_like(x2), label = 'x2 VS (x2)*2')
bottom_left.plot(x1, 3*np.ones_like(x1), label = 'x1 VS (x1)*3')
bottom_right.plot(x2, 4**np.ones_like(x2), label = 'x2 VS (x2)*4')

for a in ax.flatten(): # call the legends one shot
    a.grid(alpha=.25)
    a.legend(loc = 'upper left')
    
plt.tight_layout()
    
plt.show()

# %% [markdown]
# ### 3.3 Accessing all axes

# %% [markdown]
# ## 4 Other useful plots

# %% [markdown]
# ### 4.1 Histograms

# %%
filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
data['All'] = np.loadtxt(filename, skiprows = 1)

filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
data['NUS'] = np.loadtxt(filename, skiprows = 1)

plt.style.use('bmh')

plt.hist([data['All'], data['NUS']], bins = 50, label = ['ALL', 'NUS'])

plt.xlabel('Mean of Basic Monthly Earning (S$)')
plt.ylabel('Number of Students')
plt.legend()

plt.show()

# %%
# Your code here

# %% [markdown]
# ### 4.2 Scatter plots

# %%
data = {}

for label in ['All', 'NUS']:
    filename = f'sg-gov-graduate-employment-survey_basic_monthly_mean_{label.lower()}.csv'
    data[label] = np.loadtxt(filename, skiprows = 1)
    
plt.style.use('seaborn-darkgrid')

for label, numbers in data.items():
    x = range(len(numbers))
    y = numbers
    plt.scatter(x, y, label = label, alpha = .5)
    
plt.xlabel('Position ion the list')
plt.ylabel('Mean of Basic Monthly Earning (S$)')
plt.legend()

plt.show()

# %% [markdown]
# ### 4.3 Bar charts

# %%
student_numbers = {'Life Sciences': 14, 'Physics': 12, 'Chemistry' : 8, 'Comp. Biology': 1}

majors = list(student_numbers.keys())

numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.bar(majors, numbers)
plt.xlabel('Majors')
plt.ylabel('Number of students')

plt.show()

# %% [markdown]
# ### 4.4 Pie charts

# %%
student_numbers = {'Life Sciences': 14, 'Physics': 12, 'Chemistry' : 8, 'Comp. Biology': 1}

majors = list(student_numbers.keys())

numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, labels = majors, autopct = '%1.1f%%', startangle= -90)

plt.title('Percentage of each major')

plt.show()

# %% [markdown]
# ## Exercise 1 :  Plotting data from files

# %%
#--------- Generate cosine and sine values --------#
x = np.linspace(-np.pi, np.pi, num=100, endpoint=True)
cos_x = np.cos(x)
sin_x = np.sin(x)
fun1_x = np.exp(-x) * np.cos(5 * x)
fun2_x = np.exp(-x) * np.sin(2 * x)

#------- Plot the data -------#
fig, axes = plt.subplots(nrows=2, ncols=2,
                         figsize=(12, 8),  sharey='row', sharex = True)

#------- Subplot 1 -------#
axes[0, 0].plot(x, cos_x, color='r', label='$\cos x$')
axes[0, 0].plot(x, cos_x**2, color='r', linestyle=':',
                 label='$\cos^2 x$')
axes[0, 0].set_title('$\cos x$ & $\cos^2x$')
axes[0, 0].set_ylabel('Cosine Value')
axes[0, 0].set_xlim(-np.pi, np.pi)
axes[0, 0].set_ylim(-1.25, 1.25)
axes[0, 0].fill_between(x, cos_x, -2, color='r', alpha=.125)
# axes[0, 0].legend(loc = 'upper right')



#------- Subplot 2 -------#
axes[0, 1].plot(x, sin_x, color='g', label='$\sin x$')
axes[0, 1].plot(x, sin_x**2, label='$\sin^2 x$')
axes[0, 1].set_title('$sin(x)$ & $sin^2x$')
axes[0, 1].set_xlim(-np.pi, np.pi)
axes[0, 1].set_ylim(-1.25, 1.25)
axes[0, 1].fill_between(x, sin_x, -2, color='g', alpha=.125)
# axes[0, 1].legend(loc = 'upper right')


#------- Subplot 3 -------#
axes[1, 0].plot(x, fun1_x, color='b', label='$e^{-x}\cos 5x$')
axes[1, 0].set_title('$e^{-x}\cos 5x$')
axes[1, 0].set_xlim(-np.pi, np.pi)
axes[1, 0].set_ylim(-27, 15)
axes[1, 0].fill_between(x, fun1_x, -25, color='b', alpha=.125)
axes[1, 0].set_xlabel('Angle (radians)')
axes[1, 0].set_ylabel('Cosine Value')
axes[1, 0].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
axes[1, 0].set_xticklabels(['$-\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$'])
# axes[1, 0].legend(loc = 'upper right')


#------- Subplot 4 -------#
axes[1, 1].plot(x, fun2_x, color='y', label='$e^{-x}\sin 2x$')
axes[1, 1].set_title('$e^{-x}\sin 2x$')
axes[1, 1].set_xlim(-np.pi, np.pi)
axes[1, 1].set_ylim(-27, 15)
axes[1, 1].fill_between(x, fun2_x, -27, color='y', alpha=.125)
axes[1, 1].set_xlabel('Angle (radians)')
axes[1, 1].set_xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
# axes[1, 1].legend(loc = 'upper right')

# 'flatten', 'opens' the 2D array into a simple 1D array
for a in axes.flatten():
    a.grid(alpha=.5)
    a.legend(loc = 'upper right')
    
plt.tight_layout()
plt.show()
axes.flatten()
# Out:
# array([<AxesSubplot:title={'center':'$\\cos x$ & $\\cos^2x$'}, ylabel='Cosine Value'>,
#        <AxesSubplot:title={'center':'$sin(x)$ & $sin^2x$'}>,
#        <AxesSubplot:title={'center':'$e^{-x}\\cos 5x$'}, xlabel='Angle (radians)', ylabel='Cosine Value'>,
#        <AxesSubplot:title={'center':'$e^{-x}\\sin 2x$'}, xlabel='Angle (radians)'>],
#       dtype=object)
